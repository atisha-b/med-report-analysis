# %% [markdown]
# <a href="https://colab.research.google.com/github/atisha-b/med-report-analysis/blob/main/medanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
import nltk
import re
import nltk
from ast import literal_eval
from itertools import chain

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import train_test_split
from torch import optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from tqdm.notebook import tqdm
from transformers import AutoModel, AutoTokenizer

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/content/Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
train =pd.read_csv('/content/train.csv')
patiens_note = pd.read_csv('/content/patient_notes.csv')
features = pd.read_csv('/content/features.csv')
test= pd.read_csv('/content/test.csv')

# %%
print(patiens_note.shape)
print(patiens_note.nunique())
patiens_note.head()
# Out:
# (42146, 3)
# pn_num        42146
# case_num         10
# pn_history    42146
# dtype: int64
#    pn_num  case_num                                         pn_history
# 0       0         0  17-year-old male, has come to the student heal...
# 1       1         0  17 yo male with recurrent palpitations for the...
# 2       2         0  Dillon Cleveland is a 17 y.o. male patient wit...
# 3       3         0  a 17 yo m c/o palpitation started 3 mos ago; \...
# 4       4         0  17yo male with no pmh here for evaluation of p...

# %%
print(features.shape)
print(features.nunique())
features.head()
# Out:
# (143, 3)
# feature_num     143
# case_num         10
# feature_text    131
# dtype: int64
#    feature_num  case_num                                       feature_text
# 0            0         0  Family-history-of-MI-OR-Family-history-of-myoc...
# 1            1         0                 Family-history-of-thyroid-disorder
# 2            2         0                                     Chest-pressure
# 3            3         0                              Intermittent-symptoms
# 4            4         0                                        Lightheaded

# %%
print(train.shape)
print(train.nunique())
train.head()
# Out:
# (14300, 6)
# id             14300
# case_num          10
# pn_num          1000
# feature_num      143
# annotation      5201
# location        7534
# dtype: int64
#           id  case_num  pn_num  feature_num  \
# 0  00016_000         0      16            0
# 1  00016_001         0      16            1
# 2  00016_002         0      16            2
# 3  00016_003         0      16            3
# 4  00016_004         0      16            4
#
#                                  annotation              location
# 0          ['dad with recent heart attcak']           ['696 724']
# 1             ['mom with "thyroid disease']           ['668 693']
# 2                        ['chest pressure']           ['203 217']
# 3      ['intermittent episodes', 'episode']  ['70 91', '176 183']
# 4  ['felt as if he were going to pass out']           ['222 258']

# %%
print(test.shape)
print(test.nunique())
train.head()
# Out:
# (5, 4)
# id             5
# case_num       1
# pn_num         1
# feature_num    5
# dtype: int64
#           id  case_num  pn_num  feature_num  \
# 0  00016_000         0      16            0
# 1  00016_001         0      16            1
# 2  00016_002         0      16            2
# 3  00016_003         0      16            3
# 4  00016_004         0      16            4
#
#                                  annotation              location
# 0          ['dad with recent heart attcak']           ['696 724']
# 1             ['mom with "thyroid disease']           ['668 693']
# 2                        ['chest pressure']           ['203 217']
# 3      ['intermittent episodes', 'episode']  ['70 91', '176 183']
# 4  ['felt as if he were going to pass out']           ['222 258']

# %%
train.shape
# Out:
# (14300, 6)

# %%
train.isnull().sum().sum()
# Out:
# 0

# %%
patiens_note.head(5)
# Out:
#    pn_num  case_num                                         pn_history
# 0       0         0  17-year-old male, has come to the student heal...
# 1       1         0  17 yo male with recurrent palpitations for the...
# 2       2         0  Dillon Cleveland is a 17 y.o. male patient wit...
# 3       3         0  a 17 yo m c/o palpitation started 3 mos ago; \...
# 4       4         0  17yo male with no pmh here for evaluation of p...
